# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/team-base_camp-training_ground.csv')
df2 = pd.read_csv('/content/team-qualified_as-previous_appearances.csv')

# %%
df1.head()
# Out:
#              Team    Base Camp                       Training Ground
# 0         Albania        Kamen                 SportCentrum Kaiserau
# 1         Austria       Berlin                        Mommsenstadion
# 2         Belgium  Ludwigsburg  Wasenstadion, SGV Freiberg am Neckar
# 3         Croatia    Neuruppin                      Volksparkstadion
# 4  Czech Republic      Hamburg               Edmund-Plambeck-Stadion

# %%
df2.head()
# Out:
#              Team       Qualified as  Previous appearances
# 0         Albania     Group E winner                     1
# 1         Austria  Group F runner-up                     3
# 2         Belgium     Group F winner                     6
# 3         Croatia  Group D runner-up                     6
# 4  Czech Republic  Group E runner-up                    10

# %%
merged_df = pd.merge(df1, df2, how='inner')
merged_df.to_csv('merged_tables_0_1.csv', index=False)
