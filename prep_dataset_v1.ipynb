# %%
import pandas as pd

# %%
df1 = pd.read_csv('coaches_info.csv')
df2 = pd.read_csv('dataset_draft_v0.csv')

# %%
df1.head()
# Out:
#        Team      Manager Name  Installation (in years)
# 0    France  Didier Deschamps                       11
# 1   England  Gareth Southgate                        7
# 2   Croatia      Zlatko Dalic                        6
# 3   Hungary       Marco Rossi                        6
# 4  Slovenia        Matjaz Kek                        5

# %%
df2.head()
# Out:
#    FIFA Ranking     Team  Total Points  Previous Points  Change in Points  \
# 0            66  Albania       1379.40          1375.10              4.30
# 1            25  Austria       1560.03          1554.86              5.17
# 2             3  Belgium       1797.98          1795.23              2.75
# 3             9  Croatia       1728.30          1721.07              7.23
# 4            34  Czechia       1506.23          1501.47              4.76
#
#      Base Camp                       Training Ground       Qualified as  \
# 0        Kamen                 SportCentrum Kaiserau     Group E winner
# 1       Berlin                        Mommsenstadion  Group F runner-up
# 2  Ludwigsburg  Wasenstadion, SGV Freiberg am Neckar     Group F winner
# 3    Neuruppin                      Volksparkstadion  Group D runner-up
# 4      Hamburg               Edmund-Plambeck-Stadion  Group E runner-up
#
#    Previous appearances
# 0                     1
# 1                     3
# ...

# %%
df1.shape[1], df2.shape[1]
# Out:
# (3, 9)

# %%
dataset_v1 = pd.merge(df2, df1, on='Team', how='inner')

# %%
dataset_v1.to_csv('dataset_v1.csv', index=False)
